# %%
import pandas as pd
import numpy as np
from plotly import __version__
# %matplotlib inline

# %%
print(__version__)
# Out:
# 4.5.4

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode, plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#DATA
df=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.280216  0.700144 -0.140888 -0.695053
# 1  2.001588 -0.758001 -1.360350  1.805650
# 2 -0.230630  0.045310  0.194943  1.710277
# 3  0.950220 -0.669390  0.473862  0.109206
# 4  0.044182 -1.488971  1.102109 -0.077878

# %%
df2=pd.DataFrame({'Category':['A','B','C'],'Values':[42,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      42
# 1        B      43
# 2        C      50

# %%
df.iplot()
#iplot allows ot look at the values of the graphs
# Out:
# <div>
#
#
#             <div id="171f27f2-fcea-4743-b412-4b8e66043fb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("171f27f2-fcea-4743-b412-4b8e66043fb6")) {
#                     Plotly.newPlot(
#                         '171f27f2-fcea-4743-b412-4b8e66043fb6',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers')
# wihtout mode it would be connected by line
# Out:
# <div>
#
#
#             <div id="516410ad-9743-41b0-8a19-ff6953c80c3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("516410ad-9743-41b0-8a19-ff6953c80c3d")) {
#                     Plotly.newPlot(
#                         '516410ad-9743-41b0-8a19-ff6953c80c3d',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="78fdaa51-cbe6-41f4-93b4-f47277ee8e13" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("78fdaa51-cbe6-41f4-93b4-f47277ee8e13")) {
#                     Plotly.newPlot(
#                         '78fdaa51-cbe6-41f4-93b4-f47277ee8e13',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [42, 43, 50]}],
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="79119455-67de-47a1-9d42-71420545d613" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("79119455-67de-47a1-9d42-71420545d613")) {
#                     Plotly.newPlot(
#                         '79119455-67de-47a1-9d42-71420545d613',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df.sum().iplot(kind='bar')
# the function behind the iplot agregate the data
# Out:
# <div>
#
#
#             <div id="4c168d53-36f4-4610-bc88-4c2cdedf1b9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4c168d53-36f4-4610-bc88-4c2cdedf1b9c")) {
#                     Plotly.newPlot(
#                         '4c168d53-36f4-4610-bc88-4c2cdedf1b9c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [0.31413406367017144, -10.013454994775532, -6.7258909961833195, 6.353387776215103]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="6a8ed6d0-97d3-4ff7-b73d-38a8cd8a8f18" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6a8ed6d0-97d3-4ff7-b73d-38a8cd8a8f18")) {
#                     Plotly.newPlot(
#                         '6a8ed6d0-97d3-4ff7-b73d-38a8cd8a8f18',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10], 'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="8efd7b89-611a-4ae5-b3aa-e624be481834" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8efd7b89-611a-4ae5-b3aa-e624be481834")) {
#                     Plotly.newPlot(
#                         '8efd7b89-611a-4ae5-b3aa-e624be481834',
# ...

# %%
df['A'].iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="8bb5504a-1c10-4f55-adb6-5064ab3e55de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8bb5504a-1c10-4f55-adb6-5064ab3e55de")) {
#                     Plotly.newPlot(
#                         '8bb5504a-1c10-4f55-adb6-5064ab3e55de',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="bdc297ed-4a43-4e93-9942-fb26946efe1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bdc297ed-4a43-4e93-9942-fb26946efe1a")) {
#                     Plotly.newPlot(
#                         'bdc297ed-4a43-4e93-9942-fb26946efe1a',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# shows the spread between tow columns
# Out:
# <div>
#
#
#             <div id="3df5279c-bc0f-4e74-ad69-fca5f0843b12" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3df5279c-bc0f-4e74-ad69-fca5f0843b12")) {
#                     Plotly.newPlot(
#                         '3df5279c-bc0f-4e74-ad69-fca5f0843b12',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# size = 'C' means in comparison with C column
# Out:
# <div>
#
#
#             <div id="09542759-4e83-4f23-aca2-066bc034dd94" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("09542759-4e83-4f23-aca2-066bc034dd94")) {
#                     Plotly.newPlot(
#                         '09542759-4e83-4f23-aca2-066bc034dd94',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="a6c0da34-2546-4346-954f-27516ef8c3f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a6c0da34-2546-4346-954f-27516ef8c3f2")) {
#                     Plotly.newPlot(
#                         'a6c0da34-2546-4346-954f-27516ef8c3f2',
# ...
